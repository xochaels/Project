# %% [markdown]
# # DIGICLASS - PYHTON LANJUTAN

# %% [markdown]
# ## PANDAS

# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %% [markdown]
# ### 1. SERIES

# %%
series_1 = pd.Series([1,2,3,4,5])
series_1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ### 2. DataFrame

# %%
data = data = {
  'Nama':['Rafael','Arnesta'],
  'Umur':[19,20],
  'Kelas':['D','B']
}
df_1 = pd.DataFrame(data)
df_1
# Out:
#       Nama  Umur Kelas
# 0   Rafael    19     D
# 1  Arnesta    20     B

# %% [markdown]
# ### 3. Membaca file csv

# %%
df = pd.read_csv(r"D:\Kuliah\hima\UKT 2k22-2k23\UKT.csv")
df
# Out:
#       NO           NIM  ANGKATAN                          NAMA    JALUR  \
# 0      1  200907500001      2020                  Risnawati s   SNMPTN
# 1      2  200907500002      2020         Anaway Alnajah Corrs   SNMPTN
# 2      3  200907500003      2020               Rahmat Hidayat   SNMPTN
# 3      4  200907500004      2020              Junistasya Irene  SNMPTN
# 4      5  200907500005      2020                     Aisyah S   SNMPTN
# ..   ...           ...       ...                           ...      ...
# 204  205  210907502074      2021   Muhammad Mahda Piqia Kahar   MANDIRI
# 205  206  210907502075      2021               Trias abu salam  MANDIRI
# 206  207  210907502076      2021         Muh harwandana irwan   MANDIRI
# 207  208  210907502077      2021         Devi Rezky Salsabilah  MANDIRI
# 208  209  210907502078      2021               Adrian Hidayat   MANDIRI
#
#        UKT_1    UKT_2   KIPK
# 0    2400000  2400000  KIP K
# 1    3000000  3000000    NaN
# ...

# %%
df['NIM'] = df['NIM'].astype(str)
df['ANGKATAN'] = df['ANGKATAN'].astype(str)

# %%
df.set_index('NO', inplace=True)

# %% [markdown]
# ### 4. Fungsi .head()

# %%
df.head()
# Out:
#              NIM ANGKATAN                    NAMA    JALUR    UKT_1    UKT_2  \
# NO
# 1   200907500001     2020            Risnawati s   SNMPTN   2400000  2400000
# 2   200907500002     2020   Anaway Alnajah Corrs   SNMPTN   3000000  3000000
# 3   200907500003     2020         Rahmat Hidayat   SNMPTN   2250000  2250000
# 4   200907500004     2020        Junistasya Irene  SNMPTN   1750000  1250000
# 5   200907500005     2020               Aisyah S   SNMPTN   1750000  1750000
#
#      KIPK
# NO
# 1   KIP K
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN

# %%
df.head(3)
# Out:
#              NIM ANGKATAN                    NAMA    JALUR    UKT_1    UKT_2  \
# NO
# 1   200907500001     2020            Risnawati s   SNMPTN   2400000  2400000
# 2   200907500002     2020   Anaway Alnajah Corrs   SNMPTN   3000000  3000000
# 3   200907500003     2020         Rahmat Hidayat   SNMPTN   2250000  2250000
#
#      KIPK
# NO
# 1   KIP K
# 2     NaN
# 3     NaN

# %%
df.head(10)
# Out:
#              NIM ANGKATAN                    NAMA    JALUR    UKT_1    UKT_2  \
# NO
# 1   200907500001     2020            Risnawati s   SNMPTN   2400000  2400000
# 2   200907500002     2020   Anaway Alnajah Corrs   SNMPTN   3000000  3000000
# 3   200907500003     2020         Rahmat Hidayat   SNMPTN   2250000  2250000
# 4   200907500004     2020        Junistasya Irene  SNMPTN   1750000  1250000
# 5   200907500005     2020               Aisyah S   SNMPTN   1750000  1750000
# 6   200907500006     2020       Nur Amalia Qadri   SNMPTN   3000000  3000000
# 7   200907500007     2020                Nandini   SNMPTN   4000000  3000000
# 8   200907500008     2020            Muh Anugrah   SNMPTN   4000000  4000000
# 9   200907500010     2020                 Novita   SNMPTN   2400000  2400000
# 10  200907500011     2020         Riman Pangloli   SNMPTN   2400000  2400000
#
#      KIPK
# NO
# 1   KIP K
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# ...

# %% [markdown]
# ### 5. Fungsi .tail()

# %%
df.tail()
# Out:
#               NIM ANGKATAN                          NAMA    JALUR    UKT_1  \
# NO
# 205  210907502074     2021   Muhammad Mahda Piqia Kahar   MANDIRI  4500000
# 206  210907502075     2021               Trias abu salam  MANDIRI  4500000
# 207  210907502076     2021         Muh harwandana irwan   MANDIRI  4500000
# 208  210907502077     2021         Devi Rezky Salsabilah  MANDIRI  4500000
# 209  210907502078     2021               Adrian Hidayat   MANDIRI  4500000
#
#        UKT_2 KIPK
# NO
# 205  4500000  NaN
# 206  4500000  NaN
# 207  4500000  NaN
# 208  4500000  NaN
# 209  4500000  NaN

# %%
df.tail(3)
# Out:
#               NIM ANGKATAN                    NAMA    JALUR    UKT_1    UKT_2  \
# NO
# 207  210907502076     2021   Muh harwandana irwan   MANDIRI  4500000  4500000
# 208  210907502077     2021   Devi Rezky Salsabilah  MANDIRI  4500000  4500000
# 209  210907502078     2021         Adrian Hidayat   MANDIRI  4500000  4500000
#
#     KIPK
# NO
# 207  NaN
# 208  NaN
# 209  NaN

# %%
df.tail(10)
# Out:
#               NIM ANGKATAN                          NAMA    JALUR    UKT_1  \
# NO
# 200  210907502068     2021               Lucia pambunan   MANDIRI  4500000
# 201  210907502069     2021            Reni Primithasari   MANDIRI  4500000
# 202  210907502071     2021                 Ashabul Kahfi  MANDIRI  4500000
# 203  210907502072     2021        Andi Nurul Muflihunna   MANDIRI  4500000
# 204  210907502073     2021        Andi Firyal Salsabila   MANDIRI  4500000
# 205  210907502074     2021   Muhammad Mahda Piqia Kahar   MANDIRI  4500000
# 206  210907502075     2021               Trias abu salam  MANDIRI  4500000
# 207  210907502076     2021         Muh harwandana irwan   MANDIRI  4500000
# 208  210907502077     2021         Devi Rezky Salsabilah  MANDIRI  4500000
# 209  210907502078     2021               Adrian Hidayat   MANDIRI  4500000
#
#        UKT_2 KIPK
# NO
# 200  4500000  NaN
# 201  4500000  NaN
# 202  4500000  NaN
# 203  4500000  NaN
# 204  4500000  NaN
# ...

# %% [markdown]
# ### 6. Fungsi .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209 entries, 1 to 209
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NIM       209 non-null    object
#  1   ANGKATAN  209 non-null    object
#  2   NAMA      209 non-null    object
#  3   JALUR     209 non-null    object
#  4   UKT_1     209 non-null    int64
#  5   UKT_2     209 non-null    int64
#  6   KIPK      17 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 13.1+ KB

# %% [markdown]
# ### 7. Funsi .isnull().sum()

# %%
df.isnull()
# Out:
#        NIM  ANGKATAN   NAMA  JALUR  UKT_1  UKT_2   KIPK
# NO
# 1    False     False  False  False  False  False  False
# 2    False     False  False  False  False  False   True
# 3    False     False  False  False  False  False   True
# 4    False     False  False  False  False  False   True
# 5    False     False  False  False  False  False   True
# ..     ...       ...    ...    ...    ...    ...    ...
# 205  False     False  False  False  False  False   True
# 206  False     False  False  False  False  False   True
# 207  False     False  False  False  False  False   True
# 208  False     False  False  False  False  False   True
# 209  False     False  False  False  False  False   True
#
# [209 rows x 7 columns]

# %%
df.isnull().sum() #sum hanya menghitung nilai yang true
# Out:
# NIM           0
# ANGKATAN      0
# NAMA          0
# JALUR         0
# UKT_1         0
# UKT_2         0
# KIPK        192
# dtype: int64

# %% [markdown]
# ### 8. Fungsi .describe()

# %%
df.describe().apply(lambda s: s.apply('{0:.2f}'.format))
# Out:
#             UKT_1       UKT_2
# count      209.00      209.00
# mean   3602269.32  3559598.86
# std    1067994.35  1110119.63
# min     500000.00   500000.00
# 25%    3000000.00  3000000.00
# 50%    4000000.00  4000000.00
# 75%    4500000.00  4500000.00
# max    4500000.00  4500000.00

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### Import Library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. Fungsi plt.figure() dan plt.title()

# %%
plt.figure(figsize=(10,5))
plt.title('Ini adalah Judul')
plt.show()

# %% [markdown]
# ### 2. Fungsi plt.xlabel()

# %%
plt.figure(figsize=(10,5))
plt.title('Ini adalah Judul')

plt.xlabel('ini adalah x label')

plt.show()

# %% [markdown]
# ### 3. Fungsi plt.ylabel()

# %%
plt.figure(figsize=(10,5))
plt.title('Ini adalah Judul')
plt.xlabel('ini adalah x label')

plt.ylabel('ini adalah y label')

plt.show()

# %% [markdown]
# ### 4. Fungsi plt.bar()

# %%
df['ANGKATAN'].value_counts() #mengihung jumlah data yang sama
# Out:
# 2021    134
# 2020     75
# Name: ANGKATAN, dtype: int64

# %%
labels = '2021','2020'

plt.figure(figsize=(10,5))
plt.title('Perbandingan Jumlah Mahasiswa BISNIS DIGITAL ANGKATAN 2020 DAN 2021')
plt.xlabel('ANGKATAN')
plt.ylabel('MAHASISWA')

plt.bar(labels, df['ANGKATAN'].value_counts() )
plt.show()

# %% [markdown]
# ### 5. Fungsi plt.li()

# %%
plt.title('Perbandingan Jumlah Mahasiswa BISNIS DIGITAL ANGKATAN 2020 DAN 2021')
plt.pie(df['ANGKATAN'].value_counts(), labels=labels, autopct='%1.1f%%')
plt.show()
